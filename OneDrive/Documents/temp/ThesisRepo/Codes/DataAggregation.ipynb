# %%
import pandas as pd

#### SOI
soi = pd.read_csv(r"C:\Users\lisaw\OneDrive\Documents\temp\ThesisRepo\Data\Indexes\soi.long.csv")
# print(soi)

#### PDO
pdo = pd.read_csv(r"C:\Users\lisaw\OneDrive\Documents\temp\ThesisRepo\Data\Indexes\pdo.timeseries.sstens.csv")
# print(pdo)

#### AO
ao = pd.read_csv(r"C:\Users\lisaw\OneDrive\Documents\temp\ThesisRepo\Data\Indexes\ao.long.csv")
# print(ao)

#### MJO 
mjo = pd.read_csv(r"https://psl.noaa.gov/mjo/mjoindex/romi.cpcolr.1x.txt")
print(mjo)
# Out:
#        1991  1  1  0     0.12526    -0.06945     0.14323
# 0      1991  1  2  0     0.18542    -0.04887     0.19175
# 1      1991  1  3  0     0.23960    -0.03933     0.24281
# 2      1991  1  4  0     0.27446     0.01990     0.27518
# 3      1991  1  5  0     0.27714     0.07555     0.28725
# 4      1991  1  6  0     0.37999     0.23959     0.44922
# ...                                                  ...
# 12871  2026  3 30  0     0.08614    -1.63916     1.64142
# 12872  2026  3 31  0     0.14299    -1.66625     1.67238
# 12873  2026  4  1  0     0.18278    -1.68263     1.69253
# 12874  2026  4  2  0     0.15454    -1.70402     1.71101
# 12875  2026  4  3  0     0.10150    -1.65276     1.65587
#
# [12876 rows x 1 columns]
